# %%
import seaborn as sns
import numpy as np
import matplotlib as plt
import pandas as pd
import warnings
warnings.filterwarnings('ignore')

# %%
sns.__version__
# Out:
# '0.10.0'

# %%
print(dir(sns))
# Out:
# ['FacetGrid', 'JointGrid', 'PairGrid', '__builtins__', '__cached__', '__doc__', '__file__', '__loader__', '__name__', '__package__', '__path__', '__spec__', '__version__', '_orig_rc_params', 'algorithms', 'axes_style', 'axisgrid', 'barplot', 'blend_palette', 'boxenplot', 'boxplot', 'categorical', 'catplot', 'choose_colorbrewer_palette', 'choose_cubehelix_palette', 'choose_dark_palette', 'choose_diverging_palette', 'choose_light_palette', 'clustermap', 'cm', 'color_palette', 'colors', 'countplot', 'crayon_palette', 'crayons', 'cubehelix_palette', 'dark_palette', 'desaturate', 'despine', 'distplot', 'distributions', 'diverging_palette', 'dogplot', 'external', 'factorplot', 'get_dataset_names', 'heatmap', 'hls_palette', 'husl_palette', 'jointplot', 'kdeplot', 'light_palette', 'lineplot', 'lmplot', 'load_dataset', 'lvplot', 'matrix', 'miscplot', 'mpl', 'mpl_palette', 'pairplot', 'palettes', 'palplot', 'plotting_context', 'pointplot', 'rcmod', 'regplot', 'regression', 'relational', 'relpl
# ...

# %%
sns.get_dataset_names()
# Out:
# ['anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'exercise',
#  'flights',
#  'fmri',
#  'gammas',
#  'iris',
#  'mpg',
#  'planets',
#  'tips',
#  'titanic']

# %%
tips = sns.load_dataset('tips')
iris = sns.load_dataset('iris')
flights = sns.load_dataset('flights')

# %%
tips.describe()
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %%
tips.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    category
#  3   smoker      244 non-null    category
#  4   day         244 non-null    category
#  5   time        244 non-null    category
#  6   size        244 non-null    int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.3 KB

# %%
flights
# Out:
#      year      month  passengers
# 0    1949    January         112
# 1    1949   February         118
# 2    1949      March         132
# 3    1949      April         129
# 4    1949        May         121
# ..    ...        ...         ...
# 139  1960     August         606
# 140  1960  September         508
# 141  1960    October         461
# 142  1960   November         390
# 143  1960   December         432
#
# [144 rows x 3 columns]

# %%
flights.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 144 entries, 0 to 143
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   year        144 non-null    int64
#  1   month       144 non-null    category
#  2   passengers  144 non-null    int64
# dtypes: category(1), int64(2)
# memory usage: 2.9 KB

# %%
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
iris.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
# tips.shape
# tips['sex'].value_counts()
tips['smoker'].unique()
# Out:
# [No, Yes]
# Categories (2, object): [No, Yes]

# %%
import pylab as pl
pl.figure(figsize=(10,5))
sns.set_style('whitegrid')
sns.countplot(x="sex", data=tips, hue='smoker', palette="coolwarm")

# %%
sns.barplot(x="day", y="total_bill", data=tips, hue="sex", ci=None, estimator=np.median, palette="coolwarm")
# On y axis it shows the average

# %%
sns.stripplot(x='sex', y='total_bill', data=tips, hue='smoker')

# %%
sns.swarmplot(x='sex', y='total_bill', data=tips, hue='smoker')

# %%
sns.catplot(x='sex', y='total_bill', data=tips, hue='smoker', kind='strip')

# %%
sns.catplot(x='sex', y='total_bill', data=tips, hue='smoker', kind='swarm')

# %%
sns.catplot(x='sex', y='total_bill', data=tips, hue='smoker', kind='bar')

# %%
sns.boxplot(x='sex', y='total_bill', data=tips)

# %%
sns.boxplot(x='sex', y='total_bill', data=tips, hue='smoker')

# tips[tips['sex'] == 'Male']['total_bill'].median()

np.quantile(tips[tips['sex'] == 'Male']['total_bill'], .25)
# Out:
# 14.0

# %%
sns.violinplot(x='sex', y='total_bill', data=tips, hue='smoker')

# %%
sns.violinplot(x='sex', y='total_bill', data=tips, hue='smoker', split=True)

# %%
sns.violinplot(x='sex', y='total_bill', data=tips, hue='smoker', split=True, palette='coolwarm')
sns.swarmplot(x='sex', y='total_bill', data=tips)

# %%
sns.violinplot(x='day', y='total_bill', data=tips, hue='smoker', split=True, palette='coolwarm')
sns.swarmplot(x='day', y='total_bill', data=tips)

# %% [markdown]
# # Relational and Regression Plots

# %%
sns.set_style('white')
sns.scatterplot(x='total_bill', y='tip', data=tips)

# %%
sns.lineplot(x='size', y='total_bill', data=tips)

# %%
sns.lmplot(x='total_bill', y='tip', data=tips, hue='smoker', markers=['x', 'v'], palette='seismic')

# %% [markdown]
# # Distribution Plots

# %%
pt = pd.pivot_table(tips, values='total_bill', index='day', columns='sex')
pt
# Out:
# sex        Male     Female
# day
# Thur  18.714667  16.715312
# Fri   19.857000  14.145556
# Sat   20.802542  19.680357
# Sun   21.887241  19.872222

# %%
tips[tips['day'] == 'Thur']['total_bill'].mean()
# Out:
# 17.682741935483865

# %%
sns.heatmap(pt)

# %%
sns.heatmap(pt, cmap='coolwarm')

# %%
sns.heatmap(pt, cmap='coolwarm', annot=True)

# %%
sns.heatmap(pt, cmap='coolwarm', annot=True, linewidth=2)

# %%
flights
# Out:
#      year      month  passengers
# 0    1949    January         112
# 1    1949   February         118
# 2    1949      March         132
# 3    1949      April         129
# 4    1949        May         121
# ..    ...        ...         ...
# 139  1960     August         606
# 140  1960  September         508
# 141  1960    October         461
# 142  1960   November         390
# 143  1960   December         432
#
# [144 rows x 3 columns]

# %%
pl.figure(figsize=(20,20))
pt = pd.pivot_table(flights, values='passengers', index='month', columns='year')
sns.heatmap(pt, annot=True, linewidth=4, cmap='coolwarm', fmt="d")

# %%
sns.clustermap(pt, annot=True, linewidth=4, cmap='coolwarm', standard_scale=1)
